# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="https://raw.githubusercontent.com/raxlab/imt2200-data/main/media/logo.jpg"> Proyecto: "Impacto de la pandemia sobre el NEM"
# ## Semestre: 2025-2
# ## **Datos primera entrega**
# **Grupo de trabajo:** Constanza Alarcón, Carla Espinoza, Gaspar Galaz, Renato Reyes

# %% [markdown]
# ## Distintas pruebas de admisión analizadas:
#
# ### PSU:
#     -Rendición: 2003-2020, 1 por año
#     -Puntaje: 150-850
#
# ### PDT:
#     -Rendición: 2020-2022, 1 por año menos el 2022 que se realizó por primera vez Invierno y Regular
#     -Puntaje: 150-850(en las 2 primeras),  100-1000(en la última)
#
#
# ### PAES:
#     -Rendición: 2022-  , Invierno y Regular
#     -Puntaje: 100-1000

# %% [markdown]
# - "2017-2024","2017","P.D.A-2017-MATRÍCULA", "Matricula_Admisión2017", "ArchivoMat_Adm2017.csv"
# - "2017-2024","2017","P.D.A-2017-MATRÍCULA", "Matricula_Admisión2017", "Libro_CódigosADM2017_ArchivoMatricula.xlsx"
#
# - "2017-2024","2017", "P.D.A-2017-INSCRIPCIÓN","Inscritos_Admisión2017", "Libro_CódigosADM2017_ArchivoB.xlsx"
# - "2017-2024","2017", "P.D.A-2017-INSCRIPCIÓN","Inscritos_Admisión2017","ArchivoB_Adm2017.csv"
#
# - "2017-2024","2017","P.D.A-2017-POSTULACIÓN-OFERTA-ACADEMICA", "OfertaAcadémica_Admisión2017.xlsx"
#
# - "2017-2024","2017","P.D.A-2017-POSTULACIÓN-POSTULACION-SELECCION","Postulación_Admisión2017", "ArchivoD_Adm2017.csv"
# - "2017-2024","2017","P.D.A-2017-POSTULACIÓN-POSTULACION-SELECCION","Postulación_Admisión2017", "Libro_CódigosADM2017_ArchivoD.xlsx"
#
# - "2017-2024","2017","P.D.A-2017-RENDICIÓN-PERCENTILES", "Percentiles ADM2017.xlsx"
#
# - "2017-2024","2017","P.D.A-2017-RENDICIÓN-REGULAR","Rinden_Admisión2017", "ArchivoC_Adm2017.csv"
# - "2017-2024","2017","P.D.A-2017-RENDICIÓN-REGULAR","Rinden_Admisión2017", Libro_CódigosADM2017_ArchivoC.xlsx

# %% [markdown]
# # *Vemos la información que manejaremos...*

# %% [markdown]
# ### PROCESO DE ADMISIÓN - INCRIPCIÓN

# %%
import pandas as pd
from os import path 

inscripcion_csv = path.join("2017-2024","2017", "P.D.A-2017-INSCRIPCIÓN","Inscritos_Admisión2017","ArchivoB_Adm2017.csv")
inscripcion_excel = path.join("2017-2024","2017", "P.D.A-2017-INSCRIPCIÓN","Inscritos_Admisión2017", "Libro_CódigosADM2017_ArchivoB.xlsx")
ins_df = pd.read_csv(inscripcion_csv, sep= ";")
ins_excel = pd.read_excel(inscripcion_excel)

print(ins_excel)
ins_df.head(10)
# Out:
# C:\Users\const\AppData\Local\Temp\ipykernel_38744\2305978897.py:6: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ins_df = pd.read_csv(inscripcion_csv, sep= ";")
#            Variable                                        Descripción
# 0            ID_aux                 Identificador único del postulante
# 1      ANYO_PROCESO      2017, correspondiente al proceso de admisión.
# 2      NACIONALIDAD                                       Nacionalidad
# 3               NaN                                         1. Chilena
# 4               NaN                                      2. Extranjera
# ..              ...                                                ...
# 243            PACE  “PACE”.   Postulante   informado   por   el   ...
# 244  RINDIO_PROCESO  Rindió pruebas en el Proceso de Admisión:     ...
# 245             NaN                                         1. Actual.
# ...

# %% [markdown]
# ### PROCESO DE ADMISIÓN - POSTULACIÓN

# %%
#inscripcion_csv = path.join("2017-2024","2017", "P.D.A-2017-INSCRIPCIÓN","Inscritos_Admisión2017","ArchivoB_Adm2017.csv")
oferta_academica = path.join("2017-2024","2017","P.D.A-2017-POSTULACIÓN-OFERTA-ACADEMICA", "OfertaAcadémica_Admisión2017.xlsx")
#ins_df = pd.read_csv(inscripcion_csv, sep= ";")
ins_excel = pd.read_excel(oferta_academica)

ins_excel.head(5)
#ins_df.head(10)
# Out:
#    PROCESO  CODIGO_UNIV           UNIVERSIDAD  CODIGO  \
# 0     2017           11  UNIVERSIDAD DE CHILE   11001
# 1     2017           11  UNIVERSIDAD DE CHILE   11003
# 2     2017           11  UNIVERSIDAD DE CHILE   11004
# 3     2017           11  UNIVERSIDAD DE CHILE   11005
# 4     2017           11  UNIVERSIDAD DE CHILE   11011
#
#                                              CARRERA  PORC_NOTAS  \
# 0                 ARQUITECTURA, LIC. EN ARQUITECTURA          20
# 1  ACTUACIÓN TEATRAL, LIC. EN ARTES CON MENCIÓN E...          10
# 2  DISEÑO TEATRAL, LIC. EN ARTES CON MENCIÓN EN D...          10
# 3               DISEÑO, LIC. EN DISEÑO CON MENCIONES          20
# 4  ARTES PLÁSTICAS, LIC. EN ARTES CON MENCIÓN EN ...          10
#
#    PORC_RANKINK  PORC_LENGUAJE  PORC_MATEMATICA  PORC_HISTORIA  PORC_CIEN  \
# 0            20             20               30             10         10
# 1            20             30               15             25          0
# ...

# %%
postulacion_csv = path.join("2017-2024","2017","P.D.A-2017-POSTULACIÓN-POSTULACION-SELECCION","Postulación_Admisión2017", "ArchivoD_Adm2017.csv")
postulacion_excel = path.join("2017-2024","2017","P.D.A-2017-POSTULACIÓN-POSTULACION-SELECCION","Postulación_Admisión2017", "Libro_CódigosADM2017_ArchivoD.xlsx")
pos_df = pd.read_csv(postulacion_csv, sep= ";")
pos_excel = pd.read_excel(postulacion_excel)

print(pos_excel.head(10))
pos_df.head(10)
# Out:
#                                             Variable  \
# 0                                             ID_aux
# 1                                     SIT_POSTULANTE
# 2                                                NaN
# 3                                                NaN
# 4  Para cada preferencia de postulación, del 1 al 10
# 5                                COD_CARRERA_PREF_XX
# 6                                     ESTADO_PREF_XX
# 7                                        PTJE_PREFXX
# 8                                   POND_ACAD_PREFXX
# 9                                                NaN
#
#                                          Descripción
# 0                 Identificador único del postulante
# 1       Código único que se asigna a cada postulante
# 2  P: Tiene por lo menos una postulación efectiva...
# 3  C: No cumple los requisitos en ninguna prefere...
# 4                                                NaN
# 5                              Código de la carrera
# ...

# %% [markdown]
# ### PROCESO DE ADMICIÓN - RENDICIÓN

# %%
percentiles = path.join("2017-2024","2017","P.D.A-2017-RENDICIÓN-PERCENTILES", "Percentiles ADM2017.xlsx")
per_excel = pd.read_excel(oferta_academica)
per_excel.head(5)
# Out:
#    PROCESO  CODIGO_UNIV           UNIVERSIDAD  CODIGO  \
# 0     2017           11  UNIVERSIDAD DE CHILE   11001
# 1     2017           11  UNIVERSIDAD DE CHILE   11003
# 2     2017           11  UNIVERSIDAD DE CHILE   11004
# 3     2017           11  UNIVERSIDAD DE CHILE   11005
# 4     2017           11  UNIVERSIDAD DE CHILE   11011
#
#                                              CARRERA  PORC_NOTAS  \
# 0                 ARQUITECTURA, LIC. EN ARQUITECTURA          20
# 1  ACTUACIÓN TEATRAL, LIC. EN ARTES CON MENCIÓN E...          10
# 2  DISEÑO TEATRAL, LIC. EN ARTES CON MENCIÓN EN D...          10
# 3               DISEÑO, LIC. EN DISEÑO CON MENCIONES          20
# 4  ARTES PLÁSTICAS, LIC. EN ARTES CON MENCIÓN EN ...          10
#
#    PORC_RANKINK  PORC_LENGUAJE  PORC_MATEMATICA  PORC_HISTORIA  PORC_CIEN  \
# 0            20             20               30             10         10
# 1            20             30               15             25          0
# ...

# %%
rendicion_csv = path.join("2017-2024","2017","P.D.A-2017-RENDICIÓN-REGULAR","Rinden_Admisión2017", "ArchivoC_Adm2017.csv")
rendicion_excel = path.join("2017-2024","2017","P.D.A-2017-RENDICIÓN-REGULAR","Rinden_Admisión2017", "Libro_CódigosADM2017_ArchivoC.xlsx")
ren_df = pd.read_csv(rendicion_csv, sep= ";")
ren_excel = pd.read_excel(rendicion_excel)

print(ren_excel.head(5))
ren_df.head(10)
# Out:
#        Variable                                        Descripción
# 0        ID_aux                 Identificador único del postulante
# 1    PROM_NOTAS            Promedio de notas de la educación media
# 2      PTJE_NEM  Puntaje estándar asignado al promedio general ...
# 3  PTJE_RANKING    Puntaje estándar asignado al promedio de notas
# 4   LENG_ACTUAL   Puntaje obtenido en la prueba de Lenguaje actual
#              ID_aux    RBD  COD_ENS  GRUPO_DEPENDENCIA RAMA  SITUACION_EGRESO  \
# 0  id_0000900070001  24231      310                  2   H1                 5
# 1  id_0000900070053   6897      310                  3   H1                 5
# 2  id_0000900070056   9409      410                  3   T1                 5
# 3  id_0000900270035  12716      310                  2   H1                 5
# 4  id_0000900270060     52      310                  2   H1                 5
# 5  id_0000900270097  10915      310                  2   H1                 5
# ...

# %% [markdown]
# ### PROCESO DE ADMISIÓN - MATRÍCULA

# %%
matricula_csv = path.join("2017-2024","2017","P.D.A-2017-MATRÍCULA", "Matricula_Admisión2017", "ArchivoMat_Adm2017.csv")
matricula_excel = path.join("2017-2024","2017","P.D.A-2017-MATRÍCULA", "Matricula_Admisión2017", "Libro_CódigosADM2017_ArchivoMatricula.xlsx")
mat_df = pd.read_csv(matricula_csv, sep= ";")
mat_excel = pd.read_excel(matricula_excel)

print(mat_excel.head(5))
mat_df.head(10)
# Out:
#       Variable                                        Descripción
# 0       ID_aux                 Identificador único del postulante
# 1  CODIGO_UNIV  Código que identifica la universidad donde se ...
# 2       CODIGO  Código de la carrera donde se matriculó el/la ...
# 3          VIA                                     Matrícula vía
# 4          NaN                                         1. Regular
#             ID_aux  CODIGO_UNIV  VIA  CODIGO  PREFERENCIA PTJE_POND  \
# 0  id_309743076974         16.0    1   16035            1     672,1
# 1  id_583235879324         16.0    1   16038            1     665,4
# 2  id_747537477755         26.0    1   26073            1    693,35
# 3  id_727437279749         41.0    1   41016            4     500,2
# 4  id_332833372283         45.0    1   45011            2     575,8
# 5  id_494204979427         21.0    1   21012            1    549,45
# 6  id_240602473067         17.0    1   17825            1    703,15
# ...

# %% [markdown]
# ## EMPEZAMOS!!
